# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#using python
# with open("nyc_weather.csv", "r") as file:
#     for line in file:
#         print(line)

# %%
type(df[["Temperature", "EST"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["EST"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Temperature"].min()
# Out:
# 20

# %%
df["EST"][df["Temperature"] == df["Temperature"].max()]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
df["EST"][df["Events"] == "Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df["WindSpeedMPH"].fillna(0, inplace = True) #FILL NAN values using zero
df["WindSpeedMPH"].fillna(df["WindSpeedMPH"].mean(), inplace = True) #fill NAN values with mean

# %% [markdown]
# ## **CREATING DF BASICS**

# %%
weather_data = {
    'day': ['1/1/2017', '2/1/2017','3/1/2017','4/1/2017','5/1/2017','7/1/2017','8/1/2017'],
    'temperature': [32,28,30,29,20, 21, 24],
    'windspeed': [6,7,10,7,4,6,8],
    'event': ['Rain', 'Snow', 'Snow', 'Hail', 'Rain', 'Hail', 'Rain']
}
weather_data['temperature'][0:2]
# Out:
# [32, 28]

# %%
type(weather_data)
# Out:
# dict

# %%
df2 = pd.DataFrame(weather_data)

# %%
df2
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 1  2/1/2017           28          7  Snow
# 2  3/1/2017           30         10  Snow
# 3  4/1/2017           29          7  Hail
# 4  5/1/2017           20          4  Rain
# 5  7/1/2017           21          6  Hail
# 6  8/1/2017           24          8  Rain

# %%
df2.shape
# Out:
# (7, 4)

# %%
df2.head()
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 1  2/1/2017           28          7  Snow
# 2  3/1/2017           30         10  Snow
# 3  4/1/2017           29          7  Hail
# 4  5/1/2017           20          4  Rain

# %%
df2.tail(3)#last n data points
# Out:
#         day  temperature  windspeed event
# 4  5/1/2017           20          4  Rain
# 5  7/1/2017           21          6  Hail
# 6  8/1/2017           24          8  Rain

# %%
new_df = df2[1:5]

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.Temperature.max()
# Out:
# 50

# %%
df2[df2['temperature']>29]
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 2  3/1/2017           30         10  Snow

# %%
df[df['Temperature'] == df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
# df['day'][df['temperature'] == df['temperature'].max()]
seri = pd.Series({'new_guy': [6,7,10,7,4,6,8]})

# %%
seri
# Out:
# new_guy    [6, 7, 10, 7, 4, 6, 8]
# dtype: object

# %%
df2['new_guy'] = seri

# %%
list(seri)[0]
# Out:
# [6, 7, 10, 7, 4, 6, 8]

# %%
df2['new_guy'] = [6, 7, 10, 7, 4, 6, 8]

# %%
df2
# Out:
#         day  temperature  windspeed event  new_guy
# 0  1/1/2017           32          6  Rain        6
# 1  2/1/2017           28          7  Snow        7
# 2  3/1/2017           30         10  Snow       10
# 3  4/1/2017           29          7  Hail        7
# 4  5/1/2017           20          4  Rain        4
# 5  7/1/2017           21          6  Hail        6
# 6  8/1/2017           24          8  Rain        8

# %%
df2.describe()
# Out:
#        temperature  windspeed    new_guy
# count     7.000000   7.000000   7.000000
# mean     26.285714   6.857143   6.857143
# std       4.644505   1.864454   1.864454
# min      20.000000   4.000000   4.000000
# 25%      22.500000   6.000000   6.000000
# 50%      28.000000   7.000000   7.000000
# 75%      29.500000   7.500000   7.500000
# max      32.000000  10.000000  10.000000
