# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
sample_data = pd.read_csv('countries.csv')
sample_data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
sample_data.plot(kind="scatter", x="year", y="population")

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.population.iloc[0]
# Out:
# 8425333

# %%
# plt.plot(sample_data.year[:5], sample_data.population[:5])
# plt.plot(sample_data.country[:5], sample_data.population[:5])
# plt.show()

# %%
data = pd.read_csv('countries.csv')

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
# Compare the population growth in the US and China

# %%
data[data.country == 'Nigeria']
# Out:
#       country  year  population
# 1128  Nigeria  1952    33119096
# 1129  Nigeria  1957    37173340
# 1130  Nigeria  1962    41871351
# 1131  Nigeria  1967    47287752
# 1132  Nigeria  1972    53740085
# 1133  Nigeria  1977    62209173
# 1134  Nigeria  1982    73039376
# 1135  Nigeria  1987    81551520
# 1136  Nigeria  1992    93364244
# 1137  Nigeria  1997   106207839
# 1138  Nigeria  2002   119901274
# 1139  Nigeria  2007   135031164

# %%
us = data[data.country == 'United States']

# %%
china = data[data.country == 'China']

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
us.population
# Out:
# 1608    157553000
# 1609    171984000
# 1610    186538000
# 1611    198712000
# 1612    209896000
# 1613    220239000
# 1614    232187835
# 1615    242803533
# 1616    256894189
# 1617    272911760
# 1618    287675526
# 1619    301139947
# Name: population, dtype: int64

# %%
us.population / us.population.iloc[0] * 100
# Out:
# 1608    100.000000
# 1609    109.159457
# 1610    118.396984
# 1611    126.123908
# 1612    133.222471
# 1613    139.787246
# 1614    147.371256
# 1615    154.109114
# 1616    163.052553
# 1617    173.219018
# 1618    182.589685
# 1619    191.135648
# Name: population, dtype: float64

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(china.year, china.population / china.population.iloc[0] * 100)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population growth (first year = 100)')
plt.show()

# %%
# plt.pie([50,50,4,12,45])

# %%
df = sample_data[sample_data["country"] == "Nigeria"]
df
# Out:
#       country  year  population
# 1128  Nigeria  1952    33119096
# 1129  Nigeria  1957    37173340
# 1130  Nigeria  1962    41871351
# 1131  Nigeria  1967    47287752
# 1132  Nigeria  1972    53740085
# 1133  Nigeria  1977    62209173
# 1134  Nigeria  1982    73039376
# 1135  Nigeria  1987    81551520
# 1136  Nigeria  1992    93364244
# 1137  Nigeria  1997   106207839
# 1138  Nigeria  2002   119901274
# 1139  Nigeria  2007   135031164

# %%
xmean = df["year"].mean()
xmean
# Out:
# 1979.5

# %%
ymean =df["population"].mean()
df["year"]
# Out:
# 1128    1952
# 1129    1957
# 1130    1962
# 1131    1967
# 1132    1972
# 1133    1977
# 1134    1982
# 1135    1987
# 1136    1992
# 1137    1997
# 1138    2002
# 1139    2007
# Name: year, dtype: int64

# %%
x_xbar = df["year"] - xmean
y_ybar = df["population"] - ymean
x_xbar
# Out:
# 1128   -27.5
# 1129   -22.5
# 1130   -17.5
# 1131   -12.5
# 1132    -7.5
# 1133    -2.5
# 1134     2.5
# 1135     7.5
# 1136    12.5
# 1137    17.5
# 1138    22.5
# 1139    27.5
# Name: year, dtype: float64

# %%
x_xbar_y_ybar = x_xbar * y_ybar

# %%
x_xbar_squared = x_xbar **2
y_ybar_squared = y_ybar **2

# %%
(y_ybar_squared)
# Out:
# 1128    1.647461e+15
# 1129    1.334783e+15
# 1130    1.013573e+15
# 1131    6.980304e+14
# 1132    3.987183e+14
# 1133    1.322234e+14
# 1134    4.470819e+11
# 1135    6.152053e+13
# 1136    3.863672e+14
# 1137    1.056238e+15
# 1138    2.133817e+15
# 1139    3.760528e+15
# Name: population, dtype: float64

# %%
r = x_xbar.sum() * y_ybar.sum() #pearsons correlation coefficient
r
x_xbar.sum()
# Out:
# 0.0
