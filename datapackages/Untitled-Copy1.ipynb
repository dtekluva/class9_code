# %%
import numpy as np

# %%
prices = np.full(100, fill_value=np.nan)
prices[[0, 25, 60, -1]] = [80., 30., 75., 50.]
prices
# Out:
# array([80., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 30.,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 75., nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 50.])

# %%
x = np.arange(len(prices))
is_valid = ~np.isnan(prices)
is_valid
~False
# Out:
# -1

# %%
x[is_valid]
# Out:
# array([ 0, 25, 60, 99])

# %%
prices[is_valid]
# Out:
# array([80., 30., 75., 50.])

# %%
prices = np.interp(x=x, xp=x[is_valid], fp=prices[is_valid])
prices
# Out:
# array([80.        , 78.        , 76.        , 74.        , 72.        ,
#        70.        , 68.        , 66.        , 64.        , 62.        ,
#        60.        , 58.        , 56.        , 54.        , 52.        ,
#        50.        , 48.        , 46.        , 44.        , 42.        ,
#        40.        , 38.        , 36.        , 34.        , 32.        ,
#        30.        , 31.28571429, 32.57142857, 33.85714286, 35.14285714,
#        36.42857143, 37.71428571, 39.        , 40.28571429, 41.57142857,
#        42.85714286, 44.14285714, 45.42857143, 46.71428571, 48.        ,
#        49.28571429, 50.57142857, 51.85714286, 53.14285714, 54.42857143,
#        55.71428571, 57.        , 58.28571429, 59.57142857, 60.85714286,
#        62.14285714, 63.42857143, 64.71428571, 66.        , 67.28571429,
#        68.57142857, 69.85714286, 71.14285714, 72.42857143, 73.71428571,
#        75.        , 74.35897436, 73.71794872, 73.07692308, 72.43589744,
#        71.79487179, 71.15384615, 70.51282051, 69.87179487, 69.23076923,
#        68.58974359, 67.94871795, 67.30769231, 66.66666667, 66.02564103,
#        65.38461538, 64.74358974, 64.1025641 , 63.46153846, 62.82051282,
#        62.17948718, 61.53846154, 60.8974359 , 60.25641026, 59.61538462,
#        58.97435897, 58.33333333, 57.69230769, 57.05128205, 56.41025641,
#        55.76923077, 55.12820513, 54.48717949, 53.84615385, 53.20512821,
#        52.56410256, 51.92307692, 51.28205128, 50.64102564, 50.        ])

# %%
prices += np.random.randn(len(prices)) * 2
prices
# Out:
# array([81.72029306, 74.77035959, 74.02779677, 71.45962402, 68.16923825,
#        73.79527778, 78.37653343, 62.38578747, 63.75798766, 62.8177818 ,
#        59.16681202, 64.65292679, 51.59221094, 60.90947334, 42.6260168 ,
#        49.55435881, 43.40295551, 46.63146919, 43.77875606, 41.48493819,
#        39.47527412, 37.56087103, 42.48725196, 24.88799578, 43.83765847,
#        18.0988891 , 41.30002456, 32.89624764, 33.28750789, 39.56994814,
#        23.99659389, 41.43988929, 49.03938845, 40.91106712, 27.59624822,
#        44.49924426, 27.03122858, 46.13585962, 50.37474377, 58.46813309,
#        51.61952088, 59.38146512, 55.04276322, 55.69725067, 58.25042074,
#        49.54609321, 75.35933593, 43.87028055, 71.14667797, 76.8030467 ,
#        62.24754729, 59.92418602, 70.61565705, 69.62587075, 61.89515931,
#        74.3717763 , 68.9411703 , 71.37124593, 79.67938345, 78.94284935,
#        71.80621017, 86.23548994, 64.71863548, 65.03252885, 70.98920123,
#        65.44560176, 71.79859064, 74.21242576, 66.68636316, 61.7289624 ,
#        63.43019724, 58.29179535, 60.79973039, 68.25491475, 67.2075544 ,
#        61.17138036, 62.45269346, 47.15926912, 53.03544644, 76.23915715,
#        61.71868089, 48.53766526, 61.46746596, 59.4619918 , 63.35323464,
#        61.83984292, 53.53333895, 65.48066509, 57.01240645, 58.27751634,
#        57.44025101, 49.88742196, 44.75800136, 44.81779116, 50.74545361,
#        50.97872256, 54.47787871, 47.47042111, 37.90641469, 33.87989939])

# %%
mn = np.argmin(prices)
mx = mn + np.argmax(prices[mn:])
kwargs = {'markersize': 12, 'linestyle': ''}
# Out:
# 18.098889103765618

# %%
import matplotlib.pyplot as plt

plt.plot(prices)
plt.title('Price History')
plt.xlabel('Time')
plt.ylabel('Price')
plt.scatter(mn, prices[mn], color='red')
plt.scatter(mx, prices[mx], color='green')
plt.grid(b=None, which='major', axis='both')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(prices)
plt.title('Price History')
plt.xlabel('Time')
plt.ylabel('Price')
plt.grid(b=None, which='major', axis='both')
plt.scatter([mn, mx], [prices[mn], prices[mx]], color=['red', 'green'])
plt.show()
